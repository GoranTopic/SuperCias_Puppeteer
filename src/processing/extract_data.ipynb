# %% [markdown]
# ### Connect to mongodb and make fure we have access to the pdf files

# %%
from pymongo import MongoClient
from gridfs import GridFS

# Connect to MongoDB
db = MongoClient('mongodb://10.49.0.6:27017')['supercias']
companies = db['companies']

#find one
comp = companies.find_one()
#print(comp['Documentos online'])
pdfs = []
#if company has documents
for value in comp['Documentos online'].values():
    if isinstance(value, list) and len(value) > 0:
        [ pdfs.append(v) for v in value ]

print(pdfs)
# Out:
# ['1000000000008_DocumentosJuridicos_CANCELACIÓN_Resolución_2007-01-03.pdf']

# %% [markdown]
# ### Make a query to get the pdfs we are interested in

# %%
# Access the GridFS collection
fs = GridFS(db, collection='companies')

# Retrieve all files from GridFS collection that have in the filen ethe substring 'Balance  Estado de Situación'
pdf_queries = fs.find({'filename': {'$regex': '.*DocumentosEconomicos.*_2023.*'}})

# print how many files were found
# this will exahust the cursor
print('found:', len(list(pdf_queries)))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:984, in Connection.receive_message(self, request_id)
#     983 try:
# --> 984     return receive_message(self, request_id, self.max_message_size)
#     985 except BaseException as error:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/network.py:267, in receive_message(conn, request_id, max_message_size)
#     266 else:
# --> 267     data = _receive_data_on_socket(conn, length - 16, deadline)
#     269 try:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/network.py:328, in _receive_data_on_socket(conn, length, deadline)
#     327         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 328     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     329 except BLOCKING_IO_ERRORS:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# Cell In[4], line 9
#       5 pdf_queries = fs.find({'filename': {'$regex': '.*DocumentosEconomicos.*_2023.*'}})
#       7 # print how many files were found
#       8 # this will exahust the cursor
# ----> 9 print('found:', len(list(pdf_queries)))
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/gridfs/grid_file.py:895, in GridOutCursor.next(self)
#     893 """Get next GridOut object from cursor."""
#     894 _disallow_transactions(self.session)
# --> 895 next_file = super().next()
#     896 return GridOut(self.__root_collection, file_document=next_file, session=self.session)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/cursor.py:1262, in Cursor.next(self)
#    1260 if self.__empty:
#    1261     raise StopIteration
# -> 1262 if len(self.__data) or self._refresh():
#    1263     return self.__data.popleft()
#    1264 else:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/cursor.py:1202, in Cursor._refresh(self)
#    1187     # Exhaust cursors don't send getMore messages.
#    1188     g = self._getmore_class(
#    1189         self.__dbname,
#    1190         self.__collname,
#    (...)
#    1200         self.__comment,
#    1201     )
# -> 1202     self.__send_message(g)
#    1204 return len(self.__data)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/mongo_client.py:1388, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1383     operation.reset()  # Reset op in case of retry.
#    1384     return server.run_operation(
#    1385         conn, operation, read_preference, self._event_listeners, unpack_res
#    1386     )
# -> 1388 return self._retryable_read(
#    1389     _cmd,
#    1390     operation.read_preference,
#    1391     operation.session,
#    1392     address=address,
#    1393     retryable=isinstance(operation, message._Query),
#    1394 )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/mongo_client.py:1535, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1533             assert last_error is not None
#    1534             raise last_error
# -> 1535         return func(session, server, conn, read_pref)
#    1536 except ServerSelectionTimeoutError:
#    1537     if retrying:
#    1538         # The application may think the write was never attempted
#    1539         # if we raise ServerSelectionTimeoutError on the retry
#    1540         # attempt. Raise the original exception instead.
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/mongo_client.py:1384, in MongoClient._run_operation.<locals>._cmd(session, server, conn, read_preference)
#    1377 def _cmd(
#    1378     session: Optional[ClientSession],
#    1379     server: Server,
#    1380     conn: Connection,
#    1381     read_preference: _ServerMode,
#    1382 ) -> Response:
#    1383     operation.reset()  # Reset op in case of retry.
# -> 1384     return server.run_operation(
#    1385         conn, operation, read_preference, self._event_listeners, unpack_res
#    1386     )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/helpers.py:315, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     312 from pymongo.pool import Connection
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except OperationFailure as exc:
#     317     if no_reauth:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/server.py:155, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     153 else:
#     154     conn.send_message(data, max_doc_size)
# --> 155     reply = conn.receive_message(request_id)
#     157 # Unpack and check for command errors.
#     158 if use_cmd:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:986, in Connection.receive_message(self, request_id)
#     984     return receive_message(self, request_id, self.max_message_size)
#     985 except BaseException as error:
# --> 986     self._raise_connection_failure(error)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:1134, in Connection._raise_connection_failure(self, error)
#    1132 # SSLError from PyOpenSSL inherits directly from Exception.
#    1133 if isinstance(error, (IOError, OSError, SSLError)):
# -> 1134     _raise_connection_failure(self.address, error)
#    1135 else:
#    1136     raise
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:406, in _raise_connection_failure(address, error, msg_prefix)
#     404     raise NetworkTimeout(msg) from error
#     405 else:
# --> 406     raise AutoReconnect(msg) from error
#
# AutoReconnect: 10.49.0.6:27017: [Errno 104] Connection reset by peer

# %% [markdown]
# ### define extract function

# %%
import os
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer 

def extract_text_from_pdf(pdf_path):
    data = {}
    try:
        lines = []
        for page_layout in extract_pages(pdf_path):
            same_y_axis = {}
            # get all the elements that are on the same y0 position
            for element in page_layout:
                if isinstance(element, LTTextContainer):
                    if element.y0 not in same_y_axis:
                        same_y_axis[element.y0] = []
                    same_y_axis[element.y0].append(element)
            # concat the lines
            for y0, elements in same_y_axis.items():
                line = []
                for element in elements:
                    text = element.get_text()
                    # sanitize the text
                    text = text.replace('\n', ' ')
                    text = text.replace('\t', ' ')
                    text = text.strip()
                    line.append({ 'y': y0, 'text': text })
                lines.append(line)
        # parse the lines
        # filter only the ones that have 2 elements
        reachedEndOfHeader = False
        reachedStartOfFooter = False
        for line in lines:
            if not reachedEndOfHeader:
                if(len(line) == 1):
                    if('ESTADO DE SITUACIÓN FINANCIERA' in line[0]['text']):
                        reachedEndOfHeader = True
                else:
                    data[line[0]['text']] = line[1]['text']
            elif reachedEndOfHeader and not reachedStartOfFooter:
                if('ESTADO DE SITUACIÓN FINANCIERA' in line[0]['text']):
                    continue
                elif('CUENTA'in line[0]['text'] and 'CÓDIGO' in line[1]['text']):
                    continue
                else:
                    data[line[0]['text']] = {}
                    if(len(line) >= 2):
                        data[line[0]['text']]['codigo'] = line[1]['text']
                    if(len(line) == 3):
                        data[line[0]['text']]['descripcion'] = line[2]['text']
                if('REPRESENTANTE(S) LEGAL(ES)' in line[0]['text']):
                    reachedStartOfFooter = True
            elif reachedStartOfFooter:
                # need to implement later
                continue
    except Exception as e:
        print('Error:', e)
    return data

# %% [markdown]
# ### for each pdf, download, extract data, push data to mongodb, remove pdf

# %%
# Write the contents of the file to a new file
path = '../../storage/pdfs/'
for pdf_query in pdf_queries:
    buffer = pdf_query.read()
    if buffer.startswith(b'%PDF'):
        # write the file to the disk
        with open( path + pdf_query.filename, 'wb') as f:
            f.write(buffer)
        # extract the text from the pdf
        data = extract_text_from_pdf(path + pdf_query.filename)
        # push to mongodb
        db['balances'].insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:932, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     931 try:
# --> 932     return command(
#     933         self,
#     934         dbname,
#     935         spec,
#     936         self.is_mongos,
#     937         read_preference,
#     938         codec_options,
#     939         session,
#     940         client,
#     941         check,
#     942         allowable_errors,
#     943         self.address,
#     944         listeners,
#     945         self.max_bson_size,
#     946         read_concern,
#     947         parse_write_concern_error=parse_write_concern_error,
#     948         collation=collation,
#     949         compression_ctx=self.compression_context,
#     950         use_op_msg=self.op_msg_enabled,
#     951         unacknowledged=unacknowledged,
#     952         user_fields=user_fields,
#     953         exhaust_allowed=exhaust_allowed,
#     954         write_concern=write_concern,
#     955     )
#     956 except (OperationFailure, NotPrimaryError):
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/network.py:181, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     180 else:
# --> 181     reply = receive_message(conn, request_id)
#     182     conn.more_to_come = reply.more_to_come
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/network.py:247, in receive_message(conn, request_id, max_message_size)
#     246 # Ignore the response's request id.
# --> 247 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     248 # No request_id for exhaust cursor "getMore".
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/network.py:328, in _receive_data_on_socket(conn, length, deadline)
#     327         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 328     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     329 except BLOCKING_IO_ERRORS:
#
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# NetworkTimeout                            Traceback (most recent call last)
# Cell In[6], line 12
#      10 data = extract_text_from_pdf(path + pdf_query.filename)
#      11 # push to mongodb
# ---> 12 db['balances'].insert_one(data)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/collection.py:671, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     667     document["_id"] = ObjectId()  # type: ignore[index]
#     669 write_concern = self._write_concern_for(session)
#     670 return InsertOneResult(
# --> 671     self._insert_one(
#     672         document,
#     673         ordered=True,
#     674         write_concern=write_concern,
#     675         op_id=None,
#     676         bypass_doc_val=bypass_document_validation,
#     677         session=session,
#     678         comment=comment,
#     679     ),
#     680     write_concern.acknowledged,
#     681 )
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/collection.py:611, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     599     result = conn.command(
#     600         self.__database.name,
#     601         command,
#    (...)
#     606         retryable_write=retryable_write,
#     607     )
#     609     _check_write_command_response(result)
# --> 611 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     613 if not isinstance(doc, RawBSONDocument):
#     614     return doc.get("_id")
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/mongo_client.py:1568, in MongoClient._retryable_write(self, retryable, func, session)
#    1566 """Internal retryable write helper."""
#    1567 with self._tmp_session(session) as s:
# -> 1568     return self._retry_with_session(retryable, func, s, None)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/mongo_client.py:1413, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1403 """Execute an operation with at most one consecutive retries
#    1404
#    1405 Returns func()'s return value on success. On error retries the same
#    (...)
#    1408 Re-raises any exception thrown by func().
#    1409 """
#    1410 retryable = bool(
#    1411     retryable and self.options.retry_writes and session and not session.in_transaction
#    1412 )
# -> 1413 return self._retry_internal(retryable, func, session, bulk)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/mongo_client.py:1460, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1458                 raise last_error
#    1459             retryable = False
# -> 1460         return func(session, conn, retryable)
#    1461 except ServerSelectionTimeoutError:
#    1462     if is_retrying():
#    1463         # The application may think the write was never attempted
#    1464         # if we raise ServerSelectionTimeoutError on the retry
#    1465         # attempt. Raise the original exception instead.
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/collection.py:599, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     596 if bypass_doc_val:
#     597     command["bypassDocumentValidation"] = True
# --> 599 result = conn.command(
#     600     self.__database.name,
#     601     command,
#     602     write_concern=write_concern,
#     603     codec_options=self.__write_response_codec_options,
#     604     session=session,
#     605     client=self.__database.client,
#     606     retryable_write=retryable_write,
#     607 )
#     609 _check_write_command_response(result)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/helpers.py:315, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     312 from pymongo.pool import Connection
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except OperationFailure as exc:
#     317     if no_reauth:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:960, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     958 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     959 except BaseException as error:
# --> 960     self._raise_connection_failure(error)
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:1134, in Connection._raise_connection_failure(self, error)
#    1132 # SSLError from PyOpenSSL inherits directly from Exception.
#    1133 if isinstance(error, (IOError, OSError, SSLError)):
# -> 1134     _raise_connection_failure(self.address, error)
#    1135 else:
#    1136     raise
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pymongo/pool.py:398, in _raise_connection_failure(address, error, msg_prefix)
#     396     msg = msg_prefix + msg
#     397 if isinstance(error, socket.timeout):
# --> 398     raise NetworkTimeout(msg) from error
#     399 elif isinstance(error, SSLError) and "timed out" in str(error):
#     400     # Eventlet does not distinguish TLS network timeouts from other
#     401     # SSLErrors (https://github.com/eventlet/eventlet/issues/692).
#     402     # Luckily, we can work around this limitation because the phrase
#     403     # 'timed out' appears in all the timeout related SSLErrors raised.
#     404     raise NetworkTimeout(msg) from error
#
# NetworkTimeout: 10.49.0.6:27017: [Errno 110] Connection timed out

# %% [markdown]
# ### Parse data from pdf

# %%
# get every file in the path directory



files = os.listdir(path)
# for file in files:
file = files[8]
# openfile and read it
text = extract_text_from_pdf(path + file)
# print(text)
print(text)
# Out:
# [{'y': 208.451, 'text': 'PAUTA GAVILANES EDISON GERARDO'}]
# [{'y': 193.47099999999998, 'text': '0102931763'}]
# [{'y': 210.451, 'text': 'null'}]
# [{'y': 195.47099999999998, 'text': 'null'}]
# [{'y': 180.47099999999998, 'text': 'null'}]
# [{'y': 97.401, 'text': 'EL REPRESENTANTE LEGAL DECLARA QUE LOS DATOS QUE CONSTAN EN ESTOS ESTADOS FINANCIEROS SON EXACTOS Y VEREDEROS. LOS ESTADOS FINANCIEROS ESTÁN ELAORADOS BAJO LAS NORMAS INTERNACIONALES DE INFORMACIÓN FINANCIERA.'}]
# [{'y': 79.95100000000001, 'text': 'SUPERINTENDENCIA DE COMPAÑÍAS, VALORES Y SEGUROS'}]
# [{'y': 57.401, 'text': 'CERTIFICO Que el presente balance ha sido enviado electrónicamente por el Representante Legal en virtud de una Declaración de Responsabilidad firmada por éste que obvia las firmas autógrafas. Esta copia es fiel reproducción del documento que consta en nuestros'}]
# {'RAZÓN SOCIAL': 'MANUEL MENDEZ CONSTRUCTORA MMCONS CIA.LTDA.', 'DIRECCIÓN': 'AV. ORDOÑEZ LASSO Y BUGANVILLA No. 1324 BARRIO: SECTOR VIRGEN DEL MILAGRO', 'EXPEDIENTE': '735350', 'RUC': '0190499898001', 'AÑO': '2021', 'FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINANCIEROS (DD/MM/AAA)': 'null', 'FORMULARIO': 'SCV.NIIF.735350.2021.1', 'ACTIVO': {'codigo': '1', 'descripcion': '400.00'}, 'ACTIVO CORRIENTE': {'codigo': '101', 'descripcion': '400.00'}, 'EFECTIVO Y EQUIVALENTES DE EFECTIVO': {'codigo': '10101', 'descripcion': '400.00'}, 'CAJA': {'codigo': '1010101', 'descripcion': '400.00'}, 'INSTITUCIONES FINANCIERAS PÚBLICAS': {'codigo': '1010102', 'descripcion': '0.00'}, 'INSTITUCIONES FINANCIERAS PRIVADAS': {'codigo': '1010103', 'descripcion': '0.00'}, 'ACTIVOS FINANCIEROS': {'codigo': '10102', 'descripcion': '0.00'}, 'ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMBIOS EN RESULTADOS': {'codigo': '101020401', 'descripcion': '0.00'}, 'RENTA VARIABLE': {'codigo': '101020301', 'descripcion': '0.00'}, 'ACCIONES Y PARTICIPACIONES': {'codigo': '10102030101', 'descripcion': '0.00'}, 'CUOTAS DE FONDOS COLECTIVOS': {'codigo': '10102030102', 'descripcion': '0.00'}, 'VALORES DE  TITULARIZACIÓN DE PARTICIPACIÓN': {'codigo': '10102030104', 'descripcion': '0.00'}, 'UNIDADES DE PARTICIPACIÓN': {'codigo': '10102030103', 'descripcion': '0.00'}, 'INVERSIONES EN EL EXTERIOR': {'codigo': '10102030222', 'descripcion': '0.00'}, 'OTROS': {'codigo': '2020504', 'descripcion': '0.00'}, 'RENTA FIJA': {'codigo': '101020302', 'descripcion': '0.00'}, 'AVALES': {'codigo': '10102030201', 'descripcion': '0.00'}, 'BONOS DEL ESTADO': {'codigo': '10102030202', 'descripcion': '0.00'}, 'BONOS DE PRENDA': {'codigo': '10102030203', 'descripcion': '0.00'}, 'CÉDULAS HIPOTECARIAS': {'codigo': '10102030204', 'descripcion': '0.00'}, 'CERTIFICADOS FINANCIEROS': {'codigo': '10102030205', 'descripcion': '0.00'}, 'CERTIFICADOS DE INVERSIÓN': {'codigo': '10102030206', 'descripcion': '0.00'}, 'CERTIFICADOS DE TESORERÍA': {'codigo': '10102030207', 'descripcion': '0.00'}, 'CERTIFICADOS DE DEPÓSITO': {'codigo': '10102030208', 'descripcion': '0.00'}, 'CUPONES': {'codigo': '10102030209', 'descripcion': '0.00'}, 'DEPÓSITOS A PLAZO': {'codigo': '10102030210', 'descripcion': '0.00'}, 'LETRAS DE CAMBIO': {'codigo': '10102030211', 'descripcion': '0.00'}, 'NOTAS DE CRÉDITO': {'codigo': '10102030212', 'descripcion': '0.00'}, 'OBLIGACIONES': {'codigo': '2020501', 'descripcion': '0.00'}, 'FACTURAS COMERCIALES NEGOCIABLES': {'codigo': '10102030214', 'descripcion': '0.00'}, 'OVERNIGHTS': {'codigo': '10102030215', 'descripcion': '0.00'}, 'OBLIGACIONES CONVERTIBLES EN ACCIONES': {'codigo': '10102030216', 'descripcion': '0.00'}, 'PAPEL COMERCIAL': {'codigo': '2020502', 'descripcion': '0.00'}, 'PAGARÉS': {'codigo': '10102030218', 'descripcion': '0.00'}, 'PÓLIZAS DE ACUMULACIÓN': {'codigo': '10102030219', 'descripcion': '0.00'}, 'TÍTULOS DEL BANCO CENTRAL': {'codigo': '10102030220', 'descripcion': '0.00'}, 'VALORES DE TITULARIZACIÓN': {'codigo': '2020503', 'descripcion': '0.00'}, 'DERIVADOS': {'codigo': '101020103', 'descripcion': '0.00'}, 'FORWARD': {'codigo': '10102010301', 'descripcion': '0.00'}, 'FUTUROS': {'codigo': '10102010302', 'descripcion': '0.00'}, 'OPCIONES': {'codigo': '10102010303', 'descripcion': '0.00'}, 'ACTIVOS FINANCIEROS DISPONIBLES PARA LA VENTA': {'codigo': '101020402', 'descripcion': '0.00'}, 'ACTIVOS FINANCIEROS MANTENIDOS HASTA EL VENCIMIENTO': {'codigo': '1020601', 'descripcion': '0.00'}, 'PROVISIÓN POR DETERIORO DE ACTIVOS FINANCIEROS': {'codigo': '1010204', 'descripcion': '0.00'}, 'DOCUMENTOS Y CUENTAS POR COBRAR NO RELACIONADOS': {'codigo': '1010205', 'descripcion': '0.00'}, 'DE ACTIVIDADES ORDINARIAS QUE GENEREN INTERESES': {'codigo': '101020501', 'descripcion': '0.00'}, 'CUENTAS Y DOCUMENTOS A COBRAR  A CLIENTES': {'codigo': '10102050201', 'descripcion': '0.00'}, 'CUENTAS Y DOCUMENTOS A COBRAR  A TERCEROS': {'codigo': '10102050202', 'descripcion': '0.00'}, 'DE ACTIVIDADES O ...

# %% [markdown]
# ### extract the text from the pdf

# %%
from pdf2image import convert_from_path

pdfs_images = []
# for every filename pdf
for filename in filenames:
    try:
        # Convert PDF to images
        images = convert_from_path(filename)

        # Save each image as a separate file
        for i, image in enumerate(images):
            pdfs_images.append(f'{filename}_{i}.jpg')
            image.save(f'{filename}_{i}.jpg', 'JPEG')
    except Exception as e:
        print(e)
        print(f'Error processing {filename}')
        continue
# Out:
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190492230001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-22.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190492273001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-15.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190492494001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-02-10.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190492508001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-23.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190492524001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-12-31.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190492648001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-16.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190492745001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-26.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493040001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-19.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493083001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-01-18.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493091001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-01-22.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493148001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-28.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493172001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-19.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493253001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-29.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493288001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-02-03.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493296001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-31.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493482001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-21.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493555001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-11-18.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <68> in hex string
# Syntax Error (3): Illegal character <74> in hex string
# Syntax Error (4): Illegal character <6d> in hex string
# Syntax Error (5): Illegal character <6c> in hex string
# Syntax Error (8): Illegal character <68> in hex string
# Syntax Error (14): Illegal character <74> in hex string
# Syntax Error (15): Illegal character <69> in hex string
# Syntax Error (16): Illegal character <74> in hex string
# Syntax Error (17): Illegal character <6c> in hex string
# Syntax Error (26): Illegal character <2f> in hex string
# Syntax Error (27): Illegal character <74> in hex string
# Syntax Error (28): Illegal character <69> in hex string
# Syntax Error (29): Illegal character <74> in hex string
# Syntax Error (30): Illegal character <6c> in hex string
# Syntax Error (34): Illegal character <2f> in hex string
# Syntax Error (35): Illegal character <68> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493598001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-31.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <68> in hex string
# Syntax Error (3): Illegal character <74> in hex string
# Syntax Error (4): Illegal character <6d> in hex string
# Syntax Error (5): Illegal character <6c> in hex string
# Syntax Error (8): Illegal character <68> in hex string
# Syntax Error (14): Illegal character <74> in hex string
# Syntax Error (15): Illegal character <69> in hex string
# Syntax Error (16): Illegal character <74> in hex string
# Syntax Error (17): Illegal character <6c> in hex string
# Syntax Error (26): Illegal character <2f> in hex string
# Syntax Error (27): Illegal character <74> in hex string
# Syntax Error (28): Illegal character <69> in hex string
# Syntax Error (29): Illegal character <74> in hex string
# Syntax Error (30): Illegal character <6c> in hex string
# Syntax Error (34): Illegal character <2f> in hex string
# Syntax Error (35): Illegal character <68> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493636001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-30.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493695001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-20.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190493881001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-10.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# ...
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190494276001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-04.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190494373001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-25.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190494411001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-05-30.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190494489001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-12-31.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190494594001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-06-30.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190494691001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-06-01.pdf
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (2): Illegal character <48> in hex string
# Syntax Error (3): Illegal character <54> in hex string
# Syntax Error (4): Illegal character <4d> in hex string
# Syntax Error (5): Illegal character <4c> in hex string
# Syntax Error (11): Illegal character <48> in hex string
# Syntax Error (20): Illegal character <73> in hex string
# Syntax Error (23): Illegal character <68> in hex string
# Syntax Error (24): Illegal character <72> in hex string
# Syntax Error (27): Illegal character <3d> in hex string
# Syntax Error (28): Illegal character <22> in hex string
# Syntax Error (29): Illegal character <2f> in hex string
# Syntax Error (30): Illegal character <22> in hex string
# Syntax Error (32): Illegal character <2f> in hex string
# Syntax Error (36): Illegal character <73> in hex string
# Syntax Error (38): Illegal character <72> in hex string
# Syntax Error (39): Illegal character <69> in hex string
# Syntax Error (40): Illegal character <70> in hex string
# Syntax Error (41): Illegal character <74> in hex string
# Syntax Error (43): Illegal character <74> in hex string
# Syntax Error (44): Illegal character <79> in hex string
# Syntax Error (45): Illegal character <70> in hex string
# Syntax Error (47): Illegal character <3d> in hex string
# Syntax Error (48): Illegal character <22> in hex string
# Syntax Error (49): Illegal character <74> in hex string
# Syntax Error (51): Illegal character <78> in hex string
# Syntax Error (52): Illegal character <74> in hex string
# Syntax Error (53): Illegal character <2f> in hex string
# Syntax Error (54): Illegal character <6a> in hex string
# Syntax Error (56): Illegal character <76> in hex string
# Syntax Error (58): Illegal character <73> in hex string
# Syntax Error (60): Illegal character <72> in hex string
# Syntax Error (61): Illegal character <69> in hex string
# Syntax Error (62): Illegal character <70> in hex string
# Syntax Error (63): Illegal character <74> in hex string
# Syntax Error (64): Illegal character <22> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error processing 0190494764001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-28.pdf
# Unable to get page count.
# I/O Error: Couldn't open file '0190494985001_DocumentosEconomicos_Balance  Estado de Situaci<c3><b3>n Financiera_2021-04-29.pdf': No such file or directory.
#
# Error processing 0190494985001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2021-04-29.pdf

# %%
import easyocr

# %pip install opencv-python-headless
reader = easyocr.Reader(['es'])
extract_info = reader.readtext('/home/terac/data-mining/supercias_second/src/clean/output_image_0.jpg')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python-headless in /home/terac/.local/lib/python3.12/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /home/terac/.local/lib/python3.12/site-packages (from opencv-python-headless) (1.26.4)
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Note: you may need to restart the kernel to use updated packages.

# %%
extract_info = [ el[1] for el in extract_info ]
print(extract_info)
# Out:
# ['REPUBLICA', 'DEL', 'ECUADOR', 'SUPERINTENDENCIA', 'DE COMPAÑIAS', '8 5', 'RESOLUCION No. 07.Q.IJ.000025', 'DRA. PIEDAD MONCAYO DE VASCONEZ', 'DIRECTORA', 'JURIDICA DEL DEPARTAMENTO', 'DE DISOLUCION Y LIQUIDACION DE COMPAÑIAS', 'co NSIDERA ND O:', 'QUE en virtud de lo dispuesto en el inciso segundo del artículo 405, de la', 'de', 'Compañías; el Superintendente de Compañías; sin ningún otro trámite', 'ordenar la', 'cancelación de la inscripción en el Registro Mercantil de las compañías cuyo trámite de', 'liquidación', 'no', 'hubiere  terminado', 'en', 'el', 'de', 'un', 'año  posterior', 'a', 'la fecha de', 'expedición de la Resolución de Disolución;', 'QUE por Resolución No.85-1-2-1-379 de 21 de', 'marzo de 1985, inscrita en el', 'Registro Mercantil del Distrito Metropolitano de Quito', 'el 6 de marzo', 'de 1986,', 'esta', 'Superintendencia', 'declaró', 'disuelta', 'a', 'la COMPAÑIA', 'AGRICOLA', 'Y PRODUCTORA', 'DE ALIMENTOS BALANCEADOS SOCIEDAD ANONIMA. (CAPRODAL SA), EN', 'LIQUIDACION, encontrándose incursa; a la presente fecha; en la disposición prevista', 'en el Considerando anterior;', 'QUE', 'la', 'Directora   Jurídica', 'de', 'Disolución', 'y Liquidación', 'de Compañías;', 'mediante Memorando No. IJ.DJDL.07.07 de 3 de enero', 'del 2007, ha emitido informe', 'favorable para que se dicte la Resolución que disponga la cancelación de la inscripción', 'de', 'la', 'COMPAÑIA', 'AGRICOLA', 'Y', 'PRODUCTORA', 'DE', 'ALIMENTOS', 'BALANCEADOS SOCIEDAD ANONIMA. (CAPRODAL SA), EN LIQUIDACION', 'en el', 'Registro Mercantil, una vez que considera', 'que se ha', 'cumplido con los requisitos', 'legales respectivos; Y', 'EN uso de las facultades conferidas por el señor Superintendente de Compañías', 'mediante Resolución No. ADM-03193 de 13 de junio del 2003;', 'RESUELVE:', 'ARTICULO', 'PRIMERO.-', 'ORDENAR', 'la', 'cancelación', 'de', 'la', 'inscripción', 'de', 'la', 'COMPAÑHA', 'AGRICOLA', 'Y', 'PRODUCTORA', 'DE', 'ALIMENTOS', 'BALANCEADOS', 'SOCIEDAD', 'ANONIMA.', '(CAPRODAL', 'SA),', 'EN', 'LIQUIDACION', 'ARTICULO', 'SEGUNDO.', 'DISPONER', 'que,', 'el', 'señor   Registrador', 'Mercantil', 'del', 'Distrito', 'Metropolitano', 'de', 'Quito:', 'a)', 'Cancele', 'la   inscripción', 'de', 'la', 'COMPAÑHA', 'AGRICOLA', 'Y PRODUCTORA', 'DE', 'ALIMENTOS', 'BALANCEADOS  SOCIEDAD', 'ANONIMA. (CAPRODAL SA) EN LIQUIDACION', 'en el Registro', 'a', 'su cargo, la', 'misma que consta inscrita bajo el No. 700, Tomo 97 de 18 de noviembre de 1966:', 'b)', 'Cancele', 'la   inscripción', 'del', 'nombramiento   del   Liquidador', 'señor   César   Espinosa', 'Orquera;', 'inscrito', 'en', 'el', 'Registro', 'Mercantil', 'del', 'Distrito', 'Mercantil', 'del', 'Distrito', 'Metropolitano de Quito; bajo el No. 2222', 'Tomo 132 de 9 de abril del 2001;y, c)Ponga', 'las notas de referencia que dispone el inciso primero del Art. 51 de la', 'de Registro.', 'Cumplido,   sentará   razón', 'y copia', 'de lo actuado remitirá', 'a', 'la Superintendencia', 'de', 'Compañías.', 'Ley', 'podrá', 'lapso', 'Ley']
