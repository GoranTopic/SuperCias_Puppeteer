# %% [markdown]
# # Extract the data from of the balances finacieros pdfs in Mongodb
# ### Connect to mongodb and make sure we have access to the pdf files

# %%
packages = ['pymongo', 'gridfs', 'concurrent.futures']
for package in packages:
    try:
        __import__(package)
    except ImportError:
        # !pip install {package}

import os
from pymongo import MongoClient
from gridfs import GridFS
from concurrent.futures import ThreadPoolExecutor


endpoint = '10.0.10.5:27017'
database = 'supercias'
collection = 'companies'

# Connect to MongoDB
db = MongoClient('mongodb://'+endpoint)[database]
collection = db[collection]

#find one
comp = collection.find_one()

docs = comp['Documentos online']['downloaded']

pdfs = []
#if company has documents
for value in docs.values():
    if isinstance(value, list) and len(value) > 0:
        [ pdfs.append(v) for v in value ]

print(pdfs)
# Out:
# ['0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_1994-09-13.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_1996-09-06.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2008-05-08.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2009-01-14.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2013-05-13.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2013-07-17.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2013-11-12.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2020-10-23.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2022-03-22.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2023-11-21.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_1994-09-09_CORDOVEZ ORTEGA JUAN XAVIER_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_1999-10-29_CORDOVEZ ORTEGA JUAN XAVIER_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2010-06-01_CORDOVEZ ORTEGA JUAN XAVIER_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2013-07-19_RAFFERTY STEVEN_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2015-10-22_MIRANDA ILLINGWORTH CARLOS RAFAEL_GERENTE GENERAL.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2020-01-20_MIRANDA ILLINGWORTH CARLOS RAFAEL_GERENTE GENERAL.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2024-05-02_ALANIS HERNANDEZ SERGIO LUIS_GERENTE GENERAL.pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2010-02-05_ROSIN SECURITIES CORP..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2010-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2012-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2012-02-08_BISCAYNE HARBOR ASSETS LLP.pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2013-02-15_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2014-04-30_INVERSIONES NUTRECO LIMITADA.pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2014-05-23_PERCONY INTERNATIONAL S.A..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2015-04-16_MOXLEY CORPORATION S.A..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2016-02-11_PERCONY INTERNATIONAL S.A..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2016-03-22_INVERSIONES NUTRECO LIMITADA.pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2009-12-08_ROSIN SECURITIES CORP..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2010-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2012-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2012-02-08_BISCAYNE HARBOR ASSETS LLP.pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2013-02-15_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2014-04-30_INVERSIONES NUTRECO LIMITADA.pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2014-05-23_PERCONY INTERNATIONAL S.A..pdf', '0991295437001_DocumentosGenerales_Formulario de I ...

# %% [markdown]
# ### Make a query to get the pdfs we are interested in

# %%
# Access the GridFS collection
fs = GridFS(db, collection='companies')

def query_files(ruc, type, title, year):
    # Retrieve all files from GridFS collection that have in the filen ethe substring 'Balance  Estado de Situación'
    pdf_queried = fs.find({'filename': {'$regex': '.*'+ruc+'.*'+type+'.*'+title+'.*'+year+'.*'}})
    return pdf_queried

ruc = ''

type = 'DocumentosEconomicos'

# 'Estado de Flujos de Efectivo'
# 'Estado de Resultado Integral'
# 'Balance  Estado de Situación Financiera'
title = 'Balance  Estado de Situación'

year = '2023'

pdf_queried = query_files(ruc, type, title, year)

# %% [markdown]
# Print the number of queries files(this will exaust the cursor so we must do another query)

# %%
# print how many files were found
# this will exahust the cursor
print('found:', len(list(pdf_queried)))

# reset the cursor
pdf_queried = query_files(ruc, type, title, year)
# Out:
# found: 18204

# %% [markdown]
# Write queries pdf to File system

# %%
# Write the contents of the file to a new file
path = '../storage/pdfs/'

# make dir path if it does not exist
if not os.path.exists(path):
    os.makedirs(path)

def write_pdf(pdf_query):
    print('reading:', pdf_query.filename)
    buffer = pdf_query.read()
    print('buffer length:', len(buffer))
    if buffer.startswith(b'%PDF'):
        # write the file to the disk
        print('writing:', pdf_query.filename)
        with open( path + pdf_query.filename, 'wb') as f:
            f.write(buffer)
        print('done writing:', pdf_query.filename)
    else:
        # write to log file
        with open('error.log', 'a') as f:
            f.write(pdf_query.filename + '\n')

# Process PDFs concurrently
#with ThreadPoolExecutor(max_workers=5) as executor:  # Adjust max_workers as needed
    #futures = [executor.submit(write_pdf, pdf_query, path, db) for pdf_query in pdf_queried]
    #for future in futures:
        #future.result()

for pdf_query in pdf_queried:
    write_pdf(pdf_query)
# Out:
# writing: 0993382494001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf
# buffer length: 74914
# writing: 0993382494001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf
# done writing: 0993382494001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf
# writing: 1391912811001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf

# %% [markdown]
# ### Define extract function which will parse the data from the Balance Estado de Situacion

# %%
# %pip install pdfminer.six
import os
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer 

def extract_text_from_pdf(pdf_path):
    data = {}
    try:
        lines = []
        for page_layout in extract_pages(pdf_path):
            same_y_axis = {}
            # get all the elements that are on the same y0 position
            for element in page_layout:
                if isinstance(element, LTTextContainer):
                    if element.y0 not in same_y_axis:
                        same_y_axis[element.y0] = []
                    same_y_axis[element.y0].append(element)
            # concat the lines
            for y0, elements in same_y_axis.items():
                line = []
                for element in elements:
                    text = element.get_text()
                    # sanitize the text
                    text = text.replace('\n', ' ')
                    text = text.replace('\t', ' ')
                    text = text.strip()
                    line.append({ 'y': y0, 'text': text })
                lines.append(line)
        # parse the lines
        # filter only the ones that have 2 elements
        reachedEndOfHeader = False
        reachedStartOfFooter = False
        for line in lines:
            if not reachedEndOfHeader:
                if(len(line) == 1):
                    if('ESTADO DE SITUACIÓN FINANCIERA' in line[0]['text']):
                        reachedEndOfHeader = True
                else:
                    data[line[0]['text']] = line[1]['text']
            elif reachedEndOfHeader and not reachedStartOfFooter:
                if('ESTADO DE SITUACIÓN FINANCIERA' in line[0]['text']):
                    continue
                elif('CUENTA'in line[0]['text'] and 'CÓDIGO' in line[1]['text']):
                    continue
                else:
                    data[line[0]['text']] = {}
                    if(len(line) >= 2):
                        data[line[0]['text']]['codigo'] = line[1]['text']
                    if(len(line) == 3):
                        data[line[0]['text']]['descripcion'] = line[2]['text']
                if('REPRESENTANTE(S) LEGAL(ES)' in line[0]['text']):
                    reachedStartOfFooter = True
            elif reachedStartOfFooter:
                # need to implement later
                continue
    except Exception as e:
        print('Error:', e)
    return data
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pdfminer.six in /home/terac/.local/lib/python3.12/site-packages (20240706)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/lib/python3.12/site-packages (from pdfminer.six) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/lib64/python3.12/site-packages (from pdfminer.six) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /usr/lib64/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six) (1.16.0)
# Requirement already satisfied: pycparser in /usr/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.20)
# Requirement already satisfied: ply==3.11 in /usr/lib/python3.12/site-packages (from pycparser->cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (3.11)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# * for each pdf, download from mongo
# * for each pdf file we run the extract parse function
# * we upload the data back to mongodb

# %%
# Write the contents of the file to a new file
path = '../storage/pdfs/'
from concurrent.futures import ThreadPoolExecutor

def process_pdf(pdf_query):
    buffer = pdf_query.read()
    if buffer.startswith(b'%PDF'):
        # write the file to the disk
        with open( path + pdf_query.filename, 'wb') as f:
            f.write(buffer)
        # extract the text from the pdf
        data = extract_text_from_pdf(path + pdf_query.filename)
        # push to mongodb
        db['balances_economicos_raw'].insert_one(data)
        # remove the file
        os.remove(path + pdf_query.filename)
    else:
        # write to log file
        with open('error.log', 'a') as f:
            f.write(pdf_query.filename + '\n')

# Process PDFs concurrently
with ThreadPoolExecutor(max_workers=5) as executor:  # Adjust max_workers as needed
    futures = [executor.submit(process_pdf, pdf_query, path, db) for pdf_query in pdf_queried]
    for future in futures:
        future.result()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 22
#      19             f.write(pdf_query.filename + '\n')
#      21 for pdf_query in pdf_queried:
# ---> 22     process_pdf(pdf_query)
#
# Cell In[22], line 5, in process_pdf(pdf_query)
#       4 def process_pdf(pdf_query):
# ----> 5     buffer = pdf_query.read()
#       6     if buffer.startswith(b'%PDF'):
#       7         # write the file to the disk
#       8         with open( path + pdf_query.filename, 'wb') as f:
#
# File ~/.local/lib/python3.12/site-packages/gridfs/grid_file.py:619, in GridOut.read(self, size)
#     604 def read(self, size: int = -1) -> bytes:
#     605     """Read at most `size` bytes from the file (less if there
#     606     isn't enough data).
#     607
#    (...)
#     617        on every call.
#     618     """
# --> 619     return self._read_size_or_line(size=size)
#
# File ~/.local/lib/python3.12/site-packages/gridfs/grid_file.py:576, in GridOut._read_size_or_line(self, size, line)
#     574     self.__position += len(chunk_data)
#     575 else:
# --> 576     buf = self.readchunk()
#     577     chunk_start = 0
#     578     chunk_data = memoryview(buf)
#
# File ~/.local/lib/python3.12/site-packages/gridfs/grid_file.py:542, in GridOut.readchunk(self)
#     537 if self.__chunk_iter is None:
#     538     self.__chunk_iter = _GridOutChunkIterator(
#     539         self, self.__chunks, self._session, chunk_number
#     540     )
# --> 542 chunk = self.__chunk_iter.next()
#     543 chunk_data = chunk["data"][self.__position % chunk_size :]
#     545 if not chunk_data:
#
# File ~/.local/lib/python3.12/site-packages/gridfs/grid_file.py:807, in _GridOutChunkIterator.next(self)
#     805 def next(self) -> Mapping[str, Any]:
#     806     try:
# --> 807         chunk = self._next_with_retry()
#     808     except StopIteration:
#     809         if self._next_chunk >= self._num_chunks:
#
# File ~/.local/lib/python3.12/site-packages/gridfs/grid_file.py:799, in _GridOutChunkIterator._next_with_retry(self)
#     797     assert self._cursor is not None
#     798 try:
# --> 799     return self._cursor.next()
#     800 except CursorNotFound:
#     801     self._cursor.close()
#
# File ~/.local/lib/python3.12/site-packages/pymongo/cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File ~/.local/lib/python3.12/site-packages/pymongo/cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File ~/.local/lib/python3.12/site-packages/pymongo/cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File ~/.local/lib/python3.12/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pymongo/mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File ~/.local/lib/python3.12/site-packages/pymongo/mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File ~/.local/lib/python3.12/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~/.local/lib/python3.12/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/.local/lib/python3.12/site-packages/pymongo/mongo_client.py:2445, in _ClientConnectionRetryable._read(self)
#    2443 if self._retrying and not self._retryable:
#    2444     self._check_last_error()
# -> 2445 return self._func(self._session, self._server, conn, read_pref)
#
# File ~/.local/lib/python3.12/site-packages/pymongo/mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File ~/.local/lib/python3.12/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/.local/lib/python3.12/site-packages/pymongo/server.py:148, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     146 else:
#     147     conn.send_message(data, max_doc_size)
# --> 148     reply = conn.receive_message(request_id)
#     150 # Unpack and check for command errors.
#     151 if use_cmd:
#
# File ~/.local/lib/python3.12/site-packages/pymongo/pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File ~/.local/lib/python3.12/site-packages/pymongo/pool.py:1020, in Connection.receive_message(self, request_id)
#    1015 """Receive a raw BSON message or raise ConnectionFailure.
#    1016
#    1017 If any exception is raised, the socket is closed.
#    1018 """
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#    1022     self._raise_connection_failure(error)
#
# File ~/.local/lib/python3.12/site-packages/pymongo/network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File ~/.local/lib/python3.12/site-packages/pymongo/network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# KeyboardInterrupt:
