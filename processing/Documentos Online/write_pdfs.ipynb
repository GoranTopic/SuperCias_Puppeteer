# %% [markdown]
# # Extract the data from of the balances finacieros pdfs in Mongodb
# ### Connect to mongodb and make sure we have access to the pdf files

# %%
packages = ['pymongo', 'gridfs', 'concurrent.futures']
for package in packages:
    try:
        __import__(package)
    except ImportError:
        # !pip install {package}

import os
from pymongo import MongoClient
from gridfs import GridFS
from concurrent.futures import ThreadPoolExecutor


endpoint = '10.0.10.5:27017'
database = 'supercias'
collection = 'companies'

# Connect to MongoDB
db = MongoClient('mongodb://'+endpoint)[database]
collection = db[collection]

#find one
comp = collection.find_one()

docs = comp['Documentos online']['downloaded']

pdfs = []
#if company has documents
for value in docs.values():
    if isinstance(value, list) and len(value) > 0:
        [ pdfs.append(v) for v in value ]

print(pdfs)
# Out:
# ['0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_1994-09-13.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_1996-09-06.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2008-05-08.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2009-01-14.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2013-05-13.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2013-07-17.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2013-11-12.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2020-10-23.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2022-03-22.pdf', '0991295437001_DocumentosGenerales_Oficio Transferencia Acciones_2023-11-21.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_1994-09-09_CORDOVEZ ORTEGA JUAN XAVIER_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_1999-10-29_CORDOVEZ ORTEGA JUAN XAVIER_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2010-06-01_CORDOVEZ ORTEGA JUAN XAVIER_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2013-07-19_RAFFERTY STEVEN_PRESIDENTE.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2015-10-22_MIRANDA ILLINGWORTH CARLOS RAFAEL_GERENTE GENERAL.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2020-01-20_MIRANDA ILLINGWORTH CARLOS RAFAEL_GERENTE GENERAL.pdf', '0991295437001_DocumentosGenerales_Oficio Nombramiento Administradores_2024-05-02_ALANIS HERNANDEZ SERGIO LUIS_GERENTE GENERAL.pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2010-02-05_ROSIN SECURITIES CORP..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2010-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2012-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2012-02-08_BISCAYNE HARBOR ASSETS LLP.pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2013-02-15_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2014-04-30_INVERSIONES NUTRECO LIMITADA.pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2014-05-23_PERCONY INTERNATIONAL S.A..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2015-04-16_MOXLEY CORPORATION S.A..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2016-02-11_PERCONY INTERNATIONAL S.A..pdf', '0991295437001_DocumentosGenerales_Oficio de Presentación de Doc. por el Adm  RL  RL Sub_2016-03-22_INVERSIONES NUTRECO LIMITADA.pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2009-12-08_ROSIN SECURITIES CORP..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2010-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2012-02-08_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2012-02-08_BISCAYNE HARBOR ASSETS LLP.pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2013-02-15_NETVENTURES GLOBAL INC..pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2014-04-30_INVERSIONES NUTRECO LIMITADA.pdf', '0991295437001_DocumentosGenerales_Formulario de Información de la Sociedad Extranjera_2014-05-23_PERCONY INTERNATIONAL S.A..pdf', '0991295437001_DocumentosGenerales_Formulario de I ...

# %% [markdown]
# ### Read from errors files

# %%
 # read from error.log file and load the content into a list

with open('error.log', 'r') as file:
    error_list = file.readlines()

# trim the newline character from the end of each line
error_list = [line.strip() for line in error_list]

print(error_list)
# Out:
# ['0190049531001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190167275001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190335100001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190049531001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190167275001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190335100001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190376982001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190390241001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190406806001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190429989001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190437604001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190446239001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190460525001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190496775001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0190502988001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0195091714001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0195098409001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0195112630001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0195119031001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-04-17.pdf', '0391020523001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0391034506001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-08-14.pdf', '0790080300001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0790084829001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0790096991001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0790150031001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791702143001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791730015001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791739403001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791780977001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791781434001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791791634001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791797144001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791822432001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791831180001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0791842882001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990052042001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990109443001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990282668001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990289751001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990341079001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990415242001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990615667001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf', '0990725225001_DocumentosEconomicos_Balance  Estado de Situación Financiera_2023-12-31.pdf',  ...

# %% [markdown]
# #### Query the files from the mondog db

# %%
# Access the GridFS collection
fs = GridFS(db, collection='companies')

error_list = ['1790016919001_DocumentosGenerales_Oficio Transferencia Acciones_1988-10-17.pdf']

def query_files(filename):
    # Retrieve all files from GridFS collection that have in the filen ethe substring 'Balance  Estado de Situación'
    pdf_queried = fs.find({'filename': {'$regex': filename}})
    return pdf_queried

# for every error_list query the file
queries = [ query_files(filename) for filename in error_list ]

print(queries)
# Out:
# [<gridfs.grid_file.GridOutCursor object at 0x7f4fe17bf4d0>]

# %% [markdown]
# #### Query the pdfs and write them

# %%
# track the time taken to read a file from GridFS and write it to the disk
path = '../storage/pdfs/'

# make dir path if it does not exist
if not os.path.exists(path):
    os.makedirs(path)

def write_pdf(pdf_query):
    pdf_query = pdf_query[0]
    buffer = pdf_query.read()
    print('buffer length:', len(buffer))
    # write the file to the disk
    print('writing:', pdf_query.filename)
    with open( path + pdf_query.filename, 'wb') as f:
        f.write(buffer)
    print('done writing:', pdf_query.filename)

# for every query, get the first file and write it to the disk
for query in queries:
    write_pdf(query)
# Out:
# buffer length: 1165329
# writing: 1790016919001_DocumentosGenerales_Oficio Transferencia Acciones_1988-10-17.pdf
# done writing: 1790016919001_DocumentosGenerales_Oficio Transferencia Acciones_1988-10-17.pdf
