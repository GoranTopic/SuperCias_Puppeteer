# %% [markdown]
# ## Extract the infromation from the pdfs fo the administradoes actuales y antiguos
# #### Connect to mongodb and make sure we have access to the excel files

# %%
## Extract the file for administradores actuales and anteriores
#### Connect to mongodb and make sure we have access to the pdf files
packages = ['pandas', 'pymongo', 'gridfs', 'concurrent.futures']
for package in packages:
    try:
        __import__(package)
    except ImportError:
        # !pip install {package}

import pandas as pd
# print all the rows and the columns of a dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from pymongo import MongoClient
# we run this so that we can access relative paths
import os, sys
parent_dir = os.path.abspath('..')
if parent_dir not in sys.path: sys.path.append(parent_dir)
from functions.GridFsFileOperations import GridFsFileOperations

endpoint = '10.0.10.5:27017'
#endpoint = '192.168.1.10:27017'
database = 'supercias'
collection_actuales = 'administradores_actuales'
collection_anterioes = 'administradores_anteriores'
path_actuales = '../../storage/administradores_actuales/'
path_anteriores = '../../storage/administradores_anteriores/'

# Connect to MongoDB
db = MongoClient('mongodb://'+endpoint)[database]
# Create instance of GridFsFileOperations
filesActuales = GridFsFileOperations(db, collection_actuales, path_actuales)
filesAnteriores = GridFsFileOperations(db, collection_anterioes, path_anteriores)

# upload collections
upload_collection_actuales = db[collection_actuales]
upload_collection_anteriores = db[collection_anterioes]

# %% [markdown]
# Read download every file and parse data into mongodb

# %% [markdown]
# First let's define the parser

# %%
from tabula.io import read_pdf


def parse_pdf(file_path):
    print(f'Parsing file: {file_path}')
    file_size = os.path.getsize(file_path)
    # Convert the size to a human-readable format (optional)
    print('File size in bytes:', file_size)
    if(file_size <= 100): return 
    # the ruc of the company is the name of the file
    ruc = file_path.split('/')[-1].split('.')[0]
    # Extraer tablas usando Tabula
    tables = read_pdf( file_path, 
                    pages='all', 
                    multiple_tables=True,
                    lattice=True)
    print(f"Se encontraron {len(tables)} tablas.")
    if len(tables) == 0: return
    # make first table into a dataframe
    df = pd.concat(tables)
    # drop columns with all NaN values
    df = df.dropna(how='all', axis=1)
    '''
        for some reason, the the pdf switches pages, 
        it splits the last row into two,
        the name of the title holder get spit where two of the names stay on the previous
        and on a almost empty row on the next page
        an find when this happens by looking in the index
        if has a single rows of NaNs it is a normal split
        it is has two, it is the continuation fo the previous name.
    '''
    # add indexes as a column
    df['index'] = df.index
    # reset the index
    df = df.reset_index(drop=True)
    # find the row where index is 1 and the IDENTIFICACION is NaN
    df_continuation =  df[(df['index'] == 1) & (df['IDENTIFICACIÓN'].isna())]
    # now for every row in df_continuation, we get the index it has
    for i  in df_continuation.index:
        # get the continuation name
        continue_name = df.iloc[i]['NOMBRE']
        # add it to 2 rows before it
        df.at[i-2, 'NOMBRE'] = str(df.at[i-2, 'NOMBRE']) + ' ' + continue_name
        # remove the row
        df = df.drop(i)
    # remove the index column
    df = df.drop(columns=['index'])
    # remove any row that has all NaN values
    df = df.dropna(how='all')
    # remov the accents from the columns
    df.columns = df.columns.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
    # remove th \r from the columns
    df.columns = df.columns.str.replace('\r', '')
    # remove the \r from the columns NOMBRE  CARGO  
    df['NOMBRE'] = df['NOMBRE'].str.replace('\r', '')
    df['CARGO'] = df['CARGO'].str.replace('\r', '')
    # conver IDENTIFICACION to an integer
    df['IDENTIFICACION'] = pd.to_numeric(df['IDENTIFICACION'], errors='coerce').astype('Int64')
    # convert the column to string
    df['IDENTIFICACION'] = df['IDENTIFICACION'].astype(str)
    # if the IDENTIFICACION has only 9 digits, we add a 0 at the beginning
    df['IDENTIFICACION'] = df['IDENTIFICACION'].apply(lambda x: '0' + x if len(x) == 9 else x)
    # add the ruc of the company
    df['RUC'] = ruc
    # remove return df
    return df


#file_test = '../../storage/administradores_actuales/1790016919001.pdf'
#file_test = '/home/terac/data-mining/supercias/storage/administradores_anteriores/0190003809001.pdf'
#file_test = "/home/terac/data-mining/supercias/storage/administradores_actuales/1791006356001.pdf"

#df = parse_pdf(file_test)
#df.head(df.shape[0])

# %%
def upload_rows(df, collection):
    collection.insert_many(df.to_dict('records'))

# %%
# get all files actuales
files_actuales = filesActuales.get_files_list()
print('found', len(files_actuales), 'files de administradores actuales')

for file in files_actuales:
    # download pdf file
    filesActuales.write_to_disk(file)
    # parse the pdf file
    df = parse_pdf(path_actuales + file)
    if(df is None): 
        os.remove(path_actuales + file)
        continue
    # upload to mongodb
    upload_rows(df, upload_collection_actuales)
    # remove the file
    os.remove(path_actuales + file)
# Out:
# found 152000 files de administradores actuales
# found 151999 files de administradores anteriores
# Parsing file: ../../storage/administradores_actuales/1790016919001.pdf
# File size in bytes: 13755
# Dec 21, 2024 3:00:51 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Dec 21, 2024 3:00:51 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0190168018001.pdf
# File size in bytes: 11252
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990004196001.pdf
# File size in bytes: 12163
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791251237001.pdf
# File size in bytes: 11627
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1790319857001.pdf
# File size in bytes: 10995
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1792352363001.pdf
# File size in bytes: 11332
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0991295437001.pdf
# File size in bytes: 11615
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0993261068001.pdf
# File size in bytes: 11021
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0992526742001.pdf
# File size in bytes: 11330
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1790059111001.pdf
# File size in bytes: 11280
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990858322001.pdf
# File size in bytes: 11333
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990017514001.pdf
# File size in bytes: 13938
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791256115001.pdf
# File size in bytes: 10991
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791408683001.pdf
# File size in bytes: 11634
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1793105521001.pdf
# File size in bytes: 10974
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1390012949001.pdf
# File size in bytes: 11296
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791844416001.pdf
# File size in bytes: 11352
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1792369428001.pdf
# File size in bytes: 11976
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990293244001.pdf
# File size in bytes: 11369
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990006687001.pdf
# File size in bytes: 11622
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0991257721001.pdf
# File size in bytes: 0
# Parsing file: ../../storage/administradores_actuales/1792634318001.pdf
# File size in bytes: 11312
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791840712001.pdf
# File size in bytes: 11321
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990023549001.pdf
# File size in bytes: 11322
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990007020001.pdf
# File size in bytes: 21431
# Se encontraron 1 tablas.
# Parsing file: ../../storage/administradores_actuales/1790004724001.pdf
# File size in bytes: 11324
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1790749509001.pdf
# File size in bytes: 11293
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0190003809001.pdf
# File size in bytes: 11341
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0992846151001.pdf
# File size in bytes: 11307
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791282299001.pdf
# File size in bytes: 11331
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1790598012001.pdf
# File size in bytes: 11641
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1792470293001.pdf
# File size in bytes: 10996
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791739205001.pdf
# File size in bytes: 11319
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791411099001.pdf
# File size in bytes: 11591
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990011214001.pdf
# File size in bytes: 12286
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791239245001.pdf
# File size in bytes: 10998
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0991327371001.pdf
# File size in bytes: 11319
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0990033110001.pdf
# File size in bytes: 11623
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/1791808045001.pdf
# File size in bytes: 11887
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0992262192001.pdf
# File size in bytes: 11298
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0590038601001.pdf
# File size in bytes: 12556
# Se encontraron 2 tablas.
# Parsing file: ../../storage/administradores_actuales/0

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 16
#      14     continue
#      15 # upload to mongodb
# ---> 16 upload_rows(df, upload_collection_actuales)
#      17 # remove the file
#      18 os.remove(path_actuales + file)
#
# Cell In[3], line 2, in upload_rows(df, collection)
#       1 def upload_rows(df, collection):
# ----> 2     collection.insert_many(df.to_dict('records'))
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:736, in _Bulk.execute(self, write_concern, session, operation)
#     734         return None
#     735 else:
# --> 736     return self.execute_command(generator, write_concern, session, operation)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:593, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     582     self._execute_command(
#     583         generator,
#     584         write_concern,
#    (...)
#     589         full_result,
#     590     )
#     592 client = self.collection.database.client
# --> 593 _ = client._retryable_write(
#     594     self.is_retryable,
#     595     retryable_bulk,
#     596     session,
#     597     operation,
#     598     bulk=self,  # type: ignore[arg-type]
#     599     operation_id=op_id,
#     600 )
#     602 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     603     _raise_bulk_write_error(full_result)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1898, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1884 """Execute an operation with consecutive retries if possible
#    1885
#    1886 Returns func()'s return value on success. On error retries the same
#    (...)
#    1895 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1896 """
#    1897 with self._tmp_session(session) as s:
# -> 1898     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1784, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1779 # Ensure that the options supports retry_writes and there is a valid session not in
#    1780 # transaction, otherwise, we will not support retry behavior for this txn.
#    1781 retryable = bool(
#    1782     retryable and self.options.retry_writes and session and not session.in_transaction
#    1783 )
# -> 1784 return self._retry_internal(
#    1785     func=func,
#    1786     session=session,
#    1787     bulk=bulk,
#    1788     operation=operation,
#    1789     retryable=retryable,
#    1790     operation_id=operation_id,
#    1791 )
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2676, in _ClientConnectionRetryable._write(self)
#    2674             self._check_last_error()
#    2675             self._retryable = False
# -> 2676         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2677 except PyMongoError as exc:
#    2678     if not self._retryable:
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:582, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     579 def retryable_bulk(
#     580     session: Optional[ClientSession], conn: Connection, retryable: bool
#     581 ) -> None:
# --> 582     self._execute_command(
#     583         generator,
#     584         write_concern,
#     585         session,
#     586         conn,
#     587         op_id,
#     588         retryable,
#     589         full_result,
#     590     )
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:527, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     525 # Run as many ops as possible in one command.
#     526 if write_concern.acknowledged:
# --> 527     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     529     # Retryable writeConcernErrors halt the execution of this run.
#     530     wce = result.get("writeConcernError", {})
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:451, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     449 else:
#     450     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 451     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     453 return result, to_send
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:263, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     261     bwc._start(cmd, request_id, docs)
#     262 try:
# --> 263     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     264     duration = datetime.datetime.now() - bwc.start_time
#     265     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/pool.py:624, in Connection.write_command(self, request_id, msg, codec_options)
#     616 """Send "insert" etc. command, returning response as a dict.
#     617
#     618 Can raise ConnectionFailure or OperationFailure.
#    (...)
#     621 :param msg: bytes, the command message.
#     622 """
#     623 self.send_message(msg, 0)
# --> 624 reply = self.receive_message(request_id)
#     625 result = reply.command_response(codec_options)
#     627 # Raises NotPrimaryError or OperationFailure.
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/pool.py:592, in Connection.receive_message(self, request_id)
#     590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
# --> 592     self._raise_connection_failure(error)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/pool.py:590, in Connection.receive_message(self, request_id)
#     585 """Receive a raw BSON message or raise ConnectionFailure.
#     586
#     587 If any exception is raised, the socket is closed.
#     588 """
#     589 try:
# --> 590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
#     592     self._raise_connection_failure(error)
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/network.py:320, in receive_message(conn, request_id, max_message_size)
#     318         deadline = None
#     319 # Ignore the response's request id.
# --> 320 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     321 # No request_id for exhaust cursor "getMore".
#     322 if request_id is not None:
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/network.py:390, in _receive_data_on_socket(conn, length, deadline)
#     388 while bytes_read < length:
#     389     try:
# --> 390         wait_for_read(conn, deadline)
#     391         # CSOT: Update timeout. When the timeout has expired perform one
#     392         # final non-blocking recv. This helps avoid spurious timeouts when
#     393         # the response is actually already buffered on the client.
#     394         if _csot.get_timeout() and deadline is not None:
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/synchronous/network.py:375, in wait_for_read(conn, deadline)
#     373     else:
#     374         timeout = _POLL_TIMEOUT
# --> 375     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     376 if conn.cancel_context.cancelled:
#     377     raise _OperationCancelled("operation cancelled")
#
# File ~/data-mining/supercias/.venv/lib/python3.12/site-packages/pymongo/socket_checker.py:66, in SocketChecker.select(self, sock, read, write, timeout)
#      62 try:
#      63     # poll() timeout is in milliseconds. select()
#      64     # timeout is in seconds.
#      65     timeout_ = None if timeout is None else timeout * 1000
# ---> 66     res = self._poller.poll(timeout_)
#      67     # poll returns a possibly-empty list containing
#      68     # (fd, event) 2-tuples for the descriptors that have
#      69     # events or errors to report. Return True if the list
#      70     # is not empty.
#      71     return bool(res)
#
# KeyboardInterrupt:

# %%
# get all files anteriores
files_anteriores = filesAnteriores.get_files_list()
print('found', len(files_anteriores), 'files de administradores anteriores')
for file in files_anteriores:
    # download pdf file
    filesAnteriores.write_to_disk(file)
    # parse the pdf file
    df = parse_pdf(path_anteriores + file)
    if(df is None): 
        os.remove(path_anteriores + file)
        continue
    # upload to mongodb
    upload_rows(df, upload_collection_anteriores)
    # remove the file
    os.remove(path_anteriores + file)
